# %% [markdown]
# <a href="https://colab.research.google.com/github/lamtruong2002/BaitapAItuan10/blob/main/loadanh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
from keras.utils import load_img, img_to_array
img=load_img('/content/drive/MyDrive/HOCAI/data/hinh-anh-meo-con-sieu-cute-scaled.jpg')
plt.imshow(img)
plt.show()

# %%
img=load_img('/content/drive/MyDrive/HOCAI/data/hinh-anh-meo-con-sieu-cute-scaled.jpg',target_size=(32,32))
plt.imshow(img)

# %%
import numpy as np

img=img_to_array(img)
img=img.reshape(1,32*32*3)
img=img.astype('float32')
img=img/255
from keras.models import load_model
model100=load_model('/content/drive/MyDrive/HOCAI/data/model.h5')
np.argmax(model100.predict(img),axis=-1)
# Out:
# 1/1 [==============================] - 0s 64ms/step
# array([99])

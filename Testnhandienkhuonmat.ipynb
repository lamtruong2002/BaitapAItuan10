# %% [markdown]
# <a href="https://colab.research.google.com/github/lamtruong2002/BaitapAItuan10/blob/main/Testnhandienkhuonmat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
from keras.utils import load_img, img_to_array
img=load_img('/content/drive/MyDrive/HOCAI/HO_DANG_TU_20146150/H(11).jpg')
plt.imshow(img)
plt.show()

# %%
#img=load_img('/content/drive/MyDrive/HOCAI/HO_DANG_TU_20146150/H(11).jpg',target_size=(40,30))
img=load_img('/content/drive/MyDrive/HOCAI/hinh/T(25).jpg',target_size=(40,30))
plt.imshow(img)

# %%
import numpy as np

img=img_to_array(img)
img=img.reshape(1,30*40*3)
img=img.astype('float32')
img=img/255
from keras.models import load_model
model2=load_model('/content/drive/MyDrive/HOCAI/data/model1.h5')
np.argmax(model2.predict(img),axis=-1)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fda44c5b0d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 64ms/step
# array([1])
